# %% [markdown]
# <a href="https://colab.research.google.com/github/baijid024/sawon/blob/master/QR_CODE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install qrcode

# %%
import qrcode as qr
img = qr.make("https://www.youtube.com/watch?v=S9bCLPwzSC0")
img.save("Baijid_1024.png")

# %%
import qrcode
from PIL import Image
qr = qrcode.QRCode(version=1,error_correction=qrcode.constants.ERROR_CORRECT_H,box_size=10,border=4)
qr.add_data("https://www.youtube.com/watch?v=S9bCLPwzSC0")
qr.make(fit=True)
img=qr.make_image(fill_color="red",back_color="white")
img.save("Baijid")
